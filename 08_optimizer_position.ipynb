# %% [markdown]
# matrix transformation only for perfect file (with path 0)

# %%
import pandas as pd
import os

from positionism.preprocessing import create_dataframe
from positionism.read import parameter
from positionism.optimizer import opti_amount_weirdos
from positionism.plot import optimizer

direc = os.getcwd() # get current working directory

# %% [markdown]
# Input

# %%
file_perfect_poscar_48n24_wo_cif = "Li6PS5Cl_type2_init"
litype = 2
litype_site = "48h2" # "24g", "48h1", "48h2"

activate_radius = 1
max_mapping_radius = 0.043
max_mapping_radius_48htype2 = 0.066
max_mapping_radius_48htype1_48htype2 = (max_mapping_radius + max_mapping_radius_48htype2) / 2

delta_coor = 0.02
range_coor = 0.05

# select the starting and ending group index of files (ascending based on energy)
n_file_start = 0
n_file_end = 54

# %%
# Replace with your file path
file_perfect_poscar_48n24 = f"{file_perfect_poscar_48n24_wo_cif}.cif"

reference_folder = "_reference_cif"
results_folder = "_results"
iter_type = "varying_position"
file_path_ori_ref_48n24 = f"./{reference_folder}/{file_perfect_poscar_48n24}"
folder_results_iter_type = f"/{results_folder}/_{iter_type}/{file_perfect_poscar_48n24_wo_cif}/"

file_name_toten = "toten_final.ods"
col_excel_geo = "geometry"
col_excel_path = "path"
dtype = {col_excel_geo: float, col_excel_path: float}
data_toten = pd.read_excel(file_name_toten, dtype=dtype, engine="odf")

foldermapping_namestyle_all = None
modif_all_litype = False
cif_namestyle_all = None
full_calculation = False

# %%
# if activate_radius == 1:
#     df_mapping_metainfo = pd.read_pickle(f'df_mapping_metainfo_{max_mapping_radius}_{file_perfect_poscar_48n24_wo_cif}.pkl') 
# elif activate_radius == 2:
#     df_mapping_metainfo = pd.read_pickle(f'df_mapping_metainfo_{max_mapping_radius}_{max_mapping_radius_48htype2}_{file_perfect_poscar_48n24_wo_cif}.pkl')
# elif activate_radius == 3:
#     df_mapping_metainfo = pd.read_pickle(f'df_mapping_metainfo_{max_mapping_radius}_{max_mapping_radius_48htype2}_{max_mapping_radius_48htype1_48htype2}_{file_perfect_poscar_48n24_wo_cif}.pkl')

# %%
df_metainfo = create_dataframe.base(data_toten, file_name="CONTCAR")
df_selectedidx = df_metainfo[['geometry','path','subdir_new_system', 'toten [eV]']].sort_values("toten [eV]", ascending=True)[n_file_start:n_file_end].reset_index().copy()
# Out:
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/create_dataframe.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_file["g+p+1"][0] = 0 # replace 1st element with 0
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/create_dataframe.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_file["g+p-1"][(df_file["g+p-1"]).size - 1] = 0.0 # replace last element with 0
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/create_dataframe.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_file["perfect_system"][df_file["geometry"].size-1] = 0.0 # hardcode the path 0/0

# %%
max_mapping_radius_init = max_mapping_radius
max_mapping_radius_48htype2_init = max_mapping_radius_48htype2

ref_positions_array = parameter.x_y_z(file_path_ori_ref_48n24, litype)

if litype == 0:
    x, y, z = ref_positions_array[0:3]
elif litype == 1:
    x, y, z = ref_positions_array[3:6]
elif litype == 2:
    x, y, z = ref_positions_array[6:9]
elif litype == 3:
    x, y, z = ref_positions_array[9:12]
elif litype == 4:
    x, y, z = ref_positions_array[12:15]
elif litype == 5:
    x, y, z = ref_positions_array[15:18]
elif litype == 6:
    x, y, z = ref_positions_array[18:21]
elif litype == 7:
    x, y, z = ref_positions_array[21:24]
elif litype == 8:
    x, y, z = ref_positions_array[24:27]
else:
    print("litype is out of range")

# %% [markdown]
# # idea: outer loop dz2 positive, then dz1 ositive and negative
# # 2nd loop: dz2 negative

# %%
max_coor_x = x + range_coor + delta_coor
# min_coor_x = x - range_coor - delta_coor
min_coor_x = -1 * max_coor_x

min_coor_y = y - range_coor - delta_coor
max_coor_y = y + range_coor + delta_coor

min_coor_z = z - range_coor - delta_coor
max_coor_z = z + range_coor + delta_coor

# %%
# Define constants
col_x = "x"
col_y = "y"
col_z = "z"
col_sumweirdosLi = "sumweirdosLi"

# Initialize DataFrame
df_x_y_z_sumweirdosLi = pd.DataFrame(columns=[col_x, col_y, col_z, col_sumweirdosLi])

# Global index
idx_df = 0

# Set to track seen (x, y, z) combinations
seen_combinations = set()

# Function to update DataFrame
def update_dataframe(next_x, next_y, next_z, sum_weirdos_Li):
    global idx_df
    df_x_y_z_sumweirdosLi.at[idx_df, col_x] = next_x
    df_x_y_z_sumweirdosLi.at[idx_df, col_y] = next_y
    df_x_y_z_sumweirdosLi.at[idx_df, col_z] = next_z
    df_x_y_z_sumweirdosLi.at[idx_df, col_sumweirdosLi] = sum_weirdos_Li
    idx_df += 1

# Function to iterate over z and x
def iterate_x_z(start_x, step_x, next_y, start_z, end_z, step_z):
    next_x = start_x
    next_z = start_z
    while (step_z > 0 and next_z <= end_z) or (step_z < 0 and next_z >= end_z):
        ref_positions_array = [next_x, next_y, next_z]
        
        # Check if combination has already been processed
        if (next_x, next_y, next_z) not in seen_combinations:
            # sum_weirdos_Li = opti_amount_weirdos.get_sum_weirdos_Li(
            #     ref_positions_array, max_mapping_radius, max_mapping_radius_48htype2, 
            #     df_selectedidx, activate_radius, file_perfect_poscar_48n24_wo_cif, 
            #     litype, iter_type
            # )
            sum_weirdos_Li = opti_amount_weirdos.get_sum_weirdos_Li(
                        ref_positions_array, max_mapping_radius, max_mapping_radius_48htype2, 
                        df_selectedidx, activate_radius, file_perfect_poscar_48n24_wo_cif, litype, iter_type, 
                        foldermapping_namestyle_all, modif_all_litype, cif_namestyle_all, full_calculation)
            print(f"x: {next_x}, y: {next_y}, z: {next_z}, idx: {idx_df}")
            update_dataframe(next_x, next_y, next_z, sum_weirdos_Li)
            seen_combinations.add((next_x, next_y, next_z))

        next_z += step_z
        next_x += step_x


# Function to iterate over y and z
def iterate_y_z(next_x, start_y, step_y, start_z, end_z, step_z):
    next_y = start_y
    next_z = start_z
    while (step_z > 0 and next_z <= end_z) or (step_z < 0 and next_z >= end_z):
        ref_positions_array = [next_x, next_y, next_z]
        
        # Check if combination has already been processed
        if (next_x, next_y, next_z) not in seen_combinations:
            sum_weirdos_Li = opti_amount_weirdos.get_sum_weirdos_Li(
                        ref_positions_array, max_mapping_radius, max_mapping_radius_48htype2, 
                        df_selectedidx, activate_radius, file_perfect_poscar_48n24_wo_cif, litype, iter_type, 
                        foldermapping_namestyle_all, modif_all_litype, cif_namestyle_all, full_calculation)
            print(f"x: {next_x}, y: {next_y}, z: {next_z}, idx: {idx_df}")
            update_dataframe(next_x, next_y, next_z, sum_weirdos_Li)
            seen_combinations.add((next_x, next_y, next_z))

        next_y += step_y
        next_z += step_z


if litype_site == "24g":
    # Main loop function
    def main_loop():
        global next_x
        # Loop 1: All forward
        next_x = x
        while next_x <= max_coor_x:
            iterate_y_z(next_x, y, delta_coor, z, max_coor_z, delta_coor)
            next_x += delta_coor

        # Loop 2: Inner loop backward
        next_x = x
        while next_x <= max_coor_x:
            iterate_y_z(next_x, y, -delta_coor, z, min_coor_z, -delta_coor)
            next_x += delta_coor

        # Loop 3: All backward
        next_x = x
        while next_x >= min_coor_x:
            iterate_y_z(next_x, y, -delta_coor, z, min_coor_z, -delta_coor)
            next_x -= delta_coor

        # Loop 4: Outer backward
        next_x = x
        while next_x >= min_coor_x:
            iterate_y_z(next_x, y, delta_coor, z, max_coor_z, delta_coor)
            next_x -= delta_coor

elif litype_site == "48h1":
    # Main loop function
    def main_loop():
        global next_y
        # Loop 1: All forward
        next_y = y
        while next_y <= max_coor_y:
            iterate_x_z(x, -delta_coor, next_y, z, max_coor_z, delta_coor)
            next_y += delta_coor

        # Loop 2: Inner loop backward
        next_y = y
        while next_y <= max_coor_y:
            iterate_x_z(x, delta_coor, next_y, z, min_coor_z, -delta_coor)
            next_y += delta_coor

        # Loop 3: All backward
        next_y = y
        while next_y >= min_coor_y:
            iterate_x_z(x, delta_coor, next_y, z, min_coor_z, -delta_coor)
            next_y -= delta_coor

        # Loop 4: Outer backward
        next_y = y
        while next_y >= min_coor_y:
            iterate_x_z(x, -delta_coor, next_y, z, max_coor_z, delta_coor)
            next_y -= delta_coor

elif litype_site == "48h2":
    # Main loop function
    def main_loop():
        global next_y
        # Loop 1: All forward
        next_y = y
        while next_y <= max_coor_y:
            iterate_x_z(x, delta_coor, next_y, z, max_coor_z, delta_coor)
            next_y += delta_coor

        # Loop 2: Inner loop backward
        next_y = y
        while next_y <= max_coor_y:
            iterate_x_z(x, -delta_coor, next_y, z, min_coor_z, -delta_coor)
            next_y += delta_coor

        # Loop 3: All backward
        next_y = y
        while next_y >= min_coor_y:
            iterate_x_z(x, -delta_coor, next_y, z, min_coor_z, -delta_coor)
            next_y -= delta_coor

        # Loop 4: Outer backward
        next_y = y
        while next_y >= min_coor_y:
            iterate_x_z(x, delta_coor, next_y, z, max_coor_z, delta_coor)
            next_y -= delta_coor

# %%
# Run the main loop
main_loop()

# Display the resulting DataFrame
print(df_x_y_z_sumweirdosLi)
# Out:
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# x: 0.047, y: 0.254, z: 0.547, idx: 0
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# /home/azka/Documents/01_Masterthesis/Atomic-Positionism/positionism/preprocessing/CONTCARorPOSCAR.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col_subdir_positive_file][idx] = destination_path
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Run the main loop
# ----> 2 main_loop()
#       4 # Display the resulting DataFrame
#       5 print(df_x_y_z_sumweirdosLi)
#
# Cell In[8], line 107, in main_loop()
#     105 next_y = y
#     106 while next_y <= max_coor_y:
# --> 107     iterate_x_z(x, -delta_coor, next_y, z, max_coor_z, delta_coor)
#     108     next_y += delta_coor
#     110 # Loop 2: Inner loop backward
#
# Cell In[8], line 39, in iterate_x_z(start_x, step_x, next_y, start_z, end_z, step_z)
#      32 # Check if combination has already been processed
#      33 if (next_x, next_y, next_z) not in seen_combinations:
#      34     # sum_weirdos_Li = opti_amount_weirdos.get_sum_weirdos_Li(
#      35     #     ref_positions_array, max_mapping_radius, max_mapping_radius_48htype2,
#      36     #     df_selectedidx, activate_radius, file_perfect_poscar_48n24_wo_cif,
#      37     #     litype, iter_type
#      38     # )
# ---> 39     sum_weirdos_Li = opti_amount_weirdos.get_sum_weirdos_Li(
#      40                 ref_positions_array, max_mapping_radius, max_mapping_radius_48htype2,
#      41                 df_selectedidx, activate_radius, file_perfect_poscar_48n24_wo_cif, litype, iter_type,
#      42                 foldermapping_namestyle_all, modif_all_litype, cif_namestyle_all, full_calculation)
#      43     print(f"x: {next_x}, y: {next_y}, z: {next_z}, idx: {idx_df}")
#      44     update_dataframe(next_x, next_y, next_z, sum_weirdos_Li)
#
# File ~/Documents/01_Masterthesis/Atomic-Positionism/positionism/optimizer/opti_amount_weirdos.py:1453, in get_sum_weirdos_Li(ref_positions_array, max_mapping_radius, max_mapping_radius_48htype2, dataframe_init, activate_radius, file_ori_ref_48n24_wo_cif, litype, iter_type, foldermapping_namestyle_all, modif_all_litype, cif_namestyle_all, full_calculation)
#    1436 func_directory.copy_rename_files(dataframe, direc_restructure_destination, file_restructure, prefix=None, savedir = True)
#    1439 # # var_c = "trf_w_linalg_orientated"
#    1440 # # Orientation.get_structure_with_linalg_orientated(dataframe, direc_restructure_destination, file_restructure, var_c)
#    1441
#    (...)
#    1450 # max_mapping_radius = 0.055
#    1451 # max_mapping_radius = 0.04197083906
# -> 1453 mapping_process(dataframe, path_perfect_poscar_48n24, direc_restructure_destination,
#    1454                     poscar_line_nr_start, poscar_line_nr_end, contcar_columns_type2,
#    1455                     lattice_constant, amount_Li, amount_P, amount_S, amount_Cl,
#    1456                     full_calculation, activate_radius, max_mapping_radius,
#    1457                     max_mapping_radius_48htype2, litype, file_ori_ref_48n24_wo_cif)
#    1459 # dataframe_sorted_toten = dataframe[["geometry","path","coor_weirdos_48htypesmerged_Li","top3_dist_weirdos_dict_Li","idx0_weirdos_Li","#weirdos_Li","toten [eV]"]].sort_values("toten [eV]", ascending=True)
#    1460 # dataframe_sorted_toten = dataframe[["geometry","path","sum_weirdos_Li","sum_mapped_48htype2_Li_new","#weirdos_Li","sum_mapped_48htypesmerged_Li_new","sum_sanitycheck_48htypesmerged_Li_new","idx0_weirdos_Li","top3_sorted_coorweirdo_dist_label_coorreference_idxweirdo_idxreference_Li","duplicate_closest24_w_data_Li","duplicate_closest24_w_data_48htype2_Li","toten [eV]"]].sort_values("toten [eV]", ascending=True)
#    1462 if litype == 0:
#
# File ~/Documents/01_Masterthesis/Atomic-Positionism/positionism/optimizer/opti_amount_weirdos.py:957, in mapping_process(dataframe, path_perfect_poscar_48n24, direc_restructure_destination, poscar_line_nr_start, poscar_line_nr_end, contcar_columns_type2, lattice_constant, amount_Li, amount_P, amount_S, amount_Cl, full_calculation, activate_radius, max_mapping_radius, max_mapping_radius_48htype2, litype, file_perfect_poscar_48n24_wo_cif)
#     954 atom_indexing.correct_idx_and_order_mapped_el(dataframe, "Li", activate_radius)
#     955 # # output_CIF.create_combine_structure(dataframe, direc_restructure_destination, amount_Li, amount_P, amount_S, var_savefilename = "mapLi")
# --> 957 labelling.weirdos_to_top_n_closestcoorref_el(dataframe, coor_structure_init_dict, "Li", litype)
#     960 if full_calculation == False:
#     961     pass
#
# File ~/Documents/01_Masterthesis/Atomic-Positionism/positionism/mapping/labelling.py:241, in weirdos_to_top_n_closestcoorref_el(dataframe, coor_structure_init_dict, el, litype)
#     239 for i in range(1, litype + 1):
#     240     for j, coor_ref_temp in enumerate(coordinate_lists[i - 1]):
# --> 241         if (coorreference == coor_ref_temp).all():
#     242             coorweirdo_dist_label_coorreference_val_el["coor"] = tuple(coor_weirdo)
#     243             coorweirdo_dist_label_coorreference_val_el["label"] = labels[i - 1]
#
# File ~/anaconda3/envs/positionism/lib/python3.11/site-packages/numpy/core/_methods.py:64, in _all(a, axis, dtype, out, keepdims, where)
#      61 def _all(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      62     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      63     if where is True:
# ---> 64         return umr_all(a, axis, dtype, out, keepdims)
#      65     return umr_all(a, axis, dtype, out, keepdims, where=where)
#
# KeyboardInterrupt:

# %%
min_sumweirdos = int(df_x_y_z_sumweirdosLi["sumweirdosLi"].min())

# %%
folder_results_iter_type

# %%
if activate_radius == 2:
    df_x_y_z_sumweirdosLi.to_excel(f'.{folder_results_iter_type}08_varying_dx_dz_{min_sumweirdos}_{max_mapping_radius}_{max_mapping_radius_48htype2}_{file_perfect_poscar_48n24_wo_cif}.xlsx', index=False)
elif activate_radius == 1:
    df_x_y_z_sumweirdosLi.to_excel(f'.{folder_results_iter_type}08_varying_dx_dz_{min_sumweirdos}_{max_mapping_radius}_{file_perfect_poscar_48n24_wo_cif}.xlsx', index=False)

# %%
# %matplotlib inline

optimizer.heatmap_x_y(df_x_y_z_sumweirdosLi, folder_results_iter_type, litype)
